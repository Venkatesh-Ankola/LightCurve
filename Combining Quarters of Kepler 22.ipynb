# %%
from lightkurve import search_targetpixelfile
import lightkurve as lk
tpf1 = lk.search_targetpixelfile("KIC 10593626", author="Kepler", cadence="long", quarter=1).download(quality_bitmask="hard")

# %%
tpf2 = lk.search_targetpixelfile("KIC 10593626", author="Kepler", cadence="long", quarter=2).download(quality_bitmask="hard")

# %%
tpf3 = lk.search_targetpixelfile("KIC 10593626", author="Kepler", cadence="long", quarter=3).download(quality_bitmask="hard")

# %%
tpf4 = lk.search_targetpixelfile("KIC 10593626", author="Kepler", cadence="long", quarter=4).download(quality_bitmask="hard")

# %%
tpf5 = lk.search_targetpixelfile("KIC 10593626", author="Kepler", cadence="long", quarter=5).download(quality_bitmask="hard")

# %%
tpf6 = lk.search_targetpixelfile("KIC 10593626", author="Kepler", cadence="long", quarter=6).download()

# %%
tpf7 = lk.search_targetpixelfile("KIC 10593626", author="Kepler", cadence="long", quarter=7).download(quality_bitmask="hard")

# %%
tpf8 = lk.search_targetpixelfile("KIC 10593626", author="Kepler", cadence="long", quarter=8).download(quality_bitmask="hard")

# %%
tpf1.create_threshold_mask(threshold=1)
# Out:
# array([[False, False, False, False, False, False, False, False],
#        [False, False, False,  True,  True,  True, False, False],
#        [False, False,  True,  True,  True,  True,  True, False],
#        [False, False,  True,  True,  True,  True,  True, False],
#        [False, False,  True,  True,  True,  True, False, False],
#        [False, False, False, False, False,  True, False, False]])

# %%
tpf2.create_threshold_mask(threshold=1)
# Out:
# array([[False, False, False, False, False, False, False, False],
#        [False, False, False,  True,  True,  True, False, False],
#        [False, False,  True,  True,  True,  True,  True, False],
#        [False, False,  True,  True,  True,  True,  True, False],
#        [False, False,  True,  True,  True,  True, False, False],
#        [False, False, False, False, False,  True, False, False]])

# %%
tpf3.create_threshold_mask(threshold=1)
# Out:
# array([[False, False, False, False, False, False, False],
#        [False, False, False,  True, False, False, False],
#        [False, False,  True,  True,  True,  True, False],
#        [False, False,  True,  True,  True,  True, False],
#        [False, False,  True,  True,  True,  True, False],
#        [False, False, False,  True,  True,  True, False]])

# %%
tpf4.create_threshold_mask(threshold=1)
# Out:
# array([[False, False, False, False, False, False, False],
#        [False, False, False,  True,  True,  True, False],
#        [False, False,  True,  True,  True,  True,  True],
#        [False, False,  True,  True,  True,  True, False],
#        [False, False, False, False,  True,  True, False]])

# %%
tpf5.create_threshold_mask(threshold=1)
# Out:
# array([[False, False, False, False, False, False, False],
#        [False, False, False,  True,  True,  True, False],
#        [False, False,  True,  True,  True,  True,  True],
#        [False, False,  True,  True,  True,  True,  True],
#        [False, False, False,  True,  True,  True, False],
#        [False, False, False, False, False, False, False]])

# %%
tpf6.create_threshold_mask(threshold=1)
# Out:
# array([[False, False, False, False, False, False, False, False],
#        [False, False, False,  True,  True,  True, False, False],
#        [False, False,  True,  True,  True,  True,  True, False],
#        [False, False,  True,  True,  True,  True,  True, False],
#        [False, False,  True,  True,  True,  True, False, False],
#        [False, False, False, False, False,  True, False, False]])

# %%
tpf7.create_threshold_mask(threshold=1)
# Out:
# array([[False, False, False, False, False, False, False],
#        [False, False, False,  True, False, False, False],
#        [False, False,  True,  True,  True,  True, False],
#        [False, False,  True,  True,  True,  True, False],
#        [False, False,  True,  True,  True,  True, False],
#        [False, False, False,  True,  True,  True, False]])

# %%
tpf8.create_threshold_mask(threshold=1)
# Out:
# array([[False, False, False, False, False, False, False],
#        [False, False, False,  True,  True,  True, False],
#        [False, False,  True,  True,  True,  True,  True],
#        [False, False,  True,  True,  True,  True, False],
#        [False, False, False, False,  True,  True, False]])

# %%
tpf1.plot(aperture_mask=tpf1.create_threshold_mask(threshold=1));

# %%
tpf2.plot(aperture_mask=tpf2.create_threshold_mask(threshold=1));

# %%
tpf3.plot(aperture_mask=tpf3.create_threshold_mask(threshold=1));

# %%
tpf4.plot(aperture_mask=tpf4.create_threshold_mask(threshold=1));

# %%
tpf5.plot(aperture_mask=tpf5.create_threshold_mask(threshold=1));

# %%
tpf6.plot(aperture_mask=tpf6.create_threshold_mask(threshold=1));

# %%
tpf7.plot(aperture_mask=tpf7.create_threshold_mask(threshold=1));

# %%
tpf8.plot(aperture_mask=tpf8.create_threshold_mask(threshold=1));

# %%
custom_mask1 = tpf1.create_threshold_mask(threshold=2, reference_pixel=(0,0))
tpf1.plot(aperture_mask=custom_mask1);

# %%
custom_mask2 = tpf2.create_threshold_mask(threshold=1, reference_pixel=(0,0))
tpf2.plot(aperture_mask=custom_mask2);

# %%
custom_mask3 = tpf3.create_threshold_mask(threshold=5, reference_pixel=(0,0))
tpf3.plot(aperture_mask=custom_mask3);

# %%
custom_mask4 = tpf4.create_threshold_mask(threshold=3, reference_pixel=(0,0))
tpf4.plot(aperture_mask=custom_mask4);

# %%
custom_mask5 = tpf5.create_threshold_mask(threshold=1, reference_pixel=(0,0))
tpf5.plot(aperture_mask=custom_mask5);

# %%
custom_mask6 = tpf6.create_threshold_mask(threshold=2, reference_pixel=(0,0))
tpf6.plot(aperture_mask=custom_mask6);

# %%
custom_mask7 = tpf7.create_threshold_mask(threshold=1, reference_pixel=(0,0))
tpf7.plot(aperture_mask=custom_mask7);

# %%
custom_mask8 = tpf8.create_threshold_mask(threshold=2, reference_pixel=(0,0))
tpf8.plot(aperture_mask=custom_mask8);

# %%
lc1 = tpf1.to_lightcurve(aperture_mask=custom_mask1)

# %%
lc2 = tpf2.to_lightcurve(aperture_mask=custom_mask2)

# %%
lc3 = tpf3.to_lightcurve(aperture_mask=custom_mask3)

# %%
lc4 = tpf4.to_lightcurve(aperture_mask=custom_mask4)

# %%
lc5 = tpf5.to_lightcurve(aperture_mask=custom_mask5)

# %%
lc6 = tpf6.to_lightcurve(aperture_mask=custom_mask6)

# %%
lc7 = tpf7.to_lightcurve(aperture_mask=custom_mask7)

# %%
lc8 = tpf8.to_lightcurve(aperture_mask=custom_mask8)

# %%
lc_collection = lk.LightCurveCollection([lc1,lc2,lc3,lc4,lc5,lc6,lc7,lc8])
stitch_lc = lc_collection.stitch()

# %%
stitch_lc.plot()
# Out:
# <AxesSubplot:xlabel='Time - 2454833 [BKJD days]', ylabel='Normalized Flux'>

# %%
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\scipy\interpolate\interpolate.py:630: RuntimeWarning: divide by zero encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# C:\Users\Administrator\anaconda3\lib\site-packages\scipy\interpolate\interpolate.py:633: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# C:\Users\Administrator\anaconda3\lib\site-packages\scipy\interpolate\interpolate.py:630: RuntimeWarning: divide by zero encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# C:\Users\Administrator\anaconda3\lib\site-packages\scipy\interpolate\interpolate.py:633: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
