# %%
from lightkurve import TessTargetPixelFile
import lightkurve as lk
tpf = TessTargetPixelFile("C:\\Users\\Administrator\\Documents\\TIC 62020444\\MAST_2023-02-10T2357\\TESS\\tess2021284114741-s0044-0000000323687123-0215-s\\tess2021284114741-s0044-0000000323687123-0215-s_tp.fits")
tpf
# Out:
# TessTargetPixelFile(TICID: 323687123)

# %%
tpf.plot(aperture_mask=tpf.pipeline_mask);

# %%
lc = tpf.to_lightcurve()
lc.scatter();

# %%
from lightkurve import TessTargetPixelFile
import lightkurve as lk
tpf2 = TessTargetPixelFile("C:\\Users\Administrator\\Documents\\TIC 62020444\\MAST_2023-02-11T0011\\TESS\\tess2021336043614-s0046-0000000323687123-0217-s\\tess2021336043614-s0046-0000000323687123-0217-s_tp.fits")
tpf2
# Out:
# TessTargetPixelFile(TICID: 323687123)

# %%
tpf2.plot(aperture_mask=tpf.pipeline_mask);

# %%
lc2 = tpf2.to_lightcurve()
lc2.scatter();

# %%
from lightkurve import TessTargetPixelFile
import lightkurve as lk
tpf1 = TessTargetPixelFile("C:\\Users\\Administrator\\Documents\\TIC 62020444\\MAST_2023-02-11T0017\\TESS\\tess2021310001228-s0045-0000000323687123-0216-s\\tess2021310001228-s0045-0000000323687123-0216-s_tp.fits")
tpf1
# Out:
# TessTargetPixelFile(TICID: 323687123)

# %%
tpf1.plot(aperture_mask=tpf.pipeline_mask);

# %%
lc1 = tpf1.to_lightcurve()
lc1.scatter();

# %%
lc_collection = lk.LightCurveCollection([lc,lc1,lc2])

# %%
stitch_lc = lc_collection.stitch()

# %%
stitch_lc.scatter()
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>
