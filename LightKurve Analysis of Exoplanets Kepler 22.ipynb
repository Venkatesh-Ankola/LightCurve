# %%
from lightkurve import search_targetpixelfile
Kepler_22 = search_targetpixelfile("Kepler-22", quarter = [1,2,3,4,5,6,7,8]).download_all()

# %%
Kepler_22.plot();

# %%
kepler_22 = Kepler_22.stitch()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 kepler_22 = Kepler_22.stitch()
#
# AttributeError: 'TargetPixelFileCollection' object has no attribute 'stitch'

# %%
light_curve = Kepler_22.to_lightcurve(aperture_mask = Kepler_22.pipeline_mask)
light_curve
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [173], in <cell line: 1>()
# ----> 1 light_curve = Kepler_22.to_lightcurve(aperture_mask = Kepler_22.pipeline_mask)
#       2 light_curve
#
# AttributeError: 'TargetPixelFileCollection' object has no attribute 'to_lightcurve'

# %%
light_curve.time , light_curve.flux
# Out:
# (<Time object: scale='tdb' format='bkjd' value=[131.51223115 131.53266555 131.55309985 ... 164.94261202 164.96304603
#   164.98348014]>,
#  <Quantity [306127.03, 306110.44, 306087.9 , ..., 308197.78, 308182.66,
#             308173.06] electron / s>)

# %%
light_curve.plot()
# Out:
# <AxesSubplot:xlabel='Time - 2454833 [BKJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
light_curve = Kepler_22.to_lightcurve(aperture_mask = "all")

# %%
light_curve.plot()
# Out:
# <AxesSubplot:xlabel='Time - 2454833 [BKJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
flat_lc = light_curve.flatten(window_length=201)
flat_lc.plot();

# %%
import lightkurve as lk
import pandas as pd
search_result = lk.search_lightcurve("Kepler-42", mission="Kepler")
search_result
# Out:
# SearchResult containing 43 data products.
#
#  #       mission      year author exptime  target_name  distance
#                                      s                   arcsec
# --- ----------------- ---- ------ ------- ------------- --------
#   0 Kepler Quarter 01 2009 Kepler    1800 kplr008561063      0.0
#   1 Kepler Quarter 02 2009 Kepler    1800 kplr008561063      0.0
#   2 Kepler Quarter 03 2009 Kepler    1800 kplr008561063      0.0
#   3 Kepler Quarter 04 2010 Kepler    1800 kplr008561063      0.0
#   4 Kepler Quarter 05 2010 Kepler    1800 kplr008561063      0.0
#   5 Kepler Quarter 06 2010 Kepler    1800 kplr008561063      0.0
#   6 Kepler Quarter 07 2010 Kepler    1800 kplr008561063      0.0
#   7 Kepler Quarter 08 2011 Kepler    1800 kplr008561063      0.0
#   8 Kepler Quarter 09 2011 Kepler      60 kplr008561063      0.0
#   9 Kepler Quarter 09 2011 Kepler      60 kplr008561063      0.0
# ...               ...  ...    ...     ...           ...      ...
# ...

# %%
fold_lc = flat_lc.fold(period=301)
fold_lc.plot()
# Out:
# <AxesSubplot:xlabel='Phase [JD]', ylabel='Normalized Flux'>

# %%
from lightkurve import TessTargetPixelFile
import lightkurve as lk
from lightkurve import TessLightCurveFile
search_result = lk.search_targetpixelfile('Kepler-22',mission='TESS', sector = 14)
# Out:
# No data found for target "Kepler-22".

# %%
from lightkurve import search_targetpixelfile
Kepler_22 = search_targetpixelfile("Kepler-22", quarter = 7).download()

# %%
Kepler_22.plot();

# %%
Kepler_22.plot_pixels()
# Out:
# <AxesSubplot:title={'center':'Target ID: 10593626, 630.16 - 660.28 [BKJD days]'}, xlabel='Time / Column (pixel)', ylabel='Flux / Row (pixel)'>

# %%
light_curve1 = Kepler_22.to_lightcurve(aperture_mask = "pipeline").normalize().plot(label='pipeline', linewidth=2);
Kepler_22.to_lightcurve(aperture_mask = "threshold").normalize().plot(light_curve1=light_curve1, label='threshold', linewidth=2);
Kepler_22.to_lightcurve(aperture_mask = "all").normalize().plot(light_curve1=light_curve1, label='all', linewidth=2);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 light_curve1 = Kepler_22.to_lightcurve(aperture_mask = "pipeline").normalize().plot(label='pipeline', linewidth=2);
#       2 Kepler_22.to_lightcurve(aperture_mask = "threshold").normalize().plot(light_curve1=light_curve1, label='threshold', linewidth=2);
#       3 Kepler_22.to_lightcurve(aperture_mask = "all").normalize().plot(light_curve1=light_curve1, label='all', linewidth=2)
#
# AttributeError: 'TargetPixelFileCollection' object has no attribute 'to_lightcurve'
