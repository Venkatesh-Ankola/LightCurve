# %%
from lightkurve import TessTargetPixelFile
import lightkurve as lk
tpf = TessTargetPixelFile("C:\\Users\\Administrator\\Documents\\TIC 62020444\\MAST_2023-02-09T1338\\TESS\\tess2019306063752-s0018-0000000379084450-0162-s\\tess2019306063752-s0018-0000000379084450-0162-s_tp.fits")
tpf
# Out:
# TessTargetPixelFile(TICID: 379084450)

# %%
tpf.plot(aperture_mask=tpf.pipeline_mask);

# %%
lc = tpf.to_lightcurve()
lc.scatter()
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>
