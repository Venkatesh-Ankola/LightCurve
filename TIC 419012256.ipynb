# %%
from lightkurve import TessTargetPixelFile
import lightkurve as lk
tpf = TessTargetPixelFile("C:\\Users\\Administrator\\Documents\\TIC 62020444\\MAST_2023-02-09T1317\\TESS\\tess2018234235059-s0002-0000000419012256-0121-s\\tess2018234235059-s0002-0000000419012256-0121-s_tp.fits")
tpf
# Out:
# TessTargetPixelFile(TICID: 419012256)

# %%
tpf.plot(aperture_mask=tpf.pipeline_mask);

# %%
lc = tpf.to_lightcurve()
lc.scatter()
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>
