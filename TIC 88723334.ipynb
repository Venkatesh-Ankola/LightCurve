# %%
from lightkurve import TessTargetPixelFile
import lightkurve as lk
tpf = TessTargetPixelFile("C:\\Users\\Administrator\\Documents\\TIC 62020444\\MAST_2023-02-09T2346\\TESS\\tess2020020091053-s0021-0000000088723334-0167-s\\tess2020020091053-s0021-0000000088723334-0167-s_tp.fits")
tpf
# Out:
# TessTargetPixelFile(TICID: 88723334)

# %%
tpf.plot(aperture_mask=tpf.pipeline_mask);

# %%
lc = tpf.to_lightcurve()
lc.scatter()
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
fold_lc = lc.fold(period=30)
fold_lc.scatter()
# Out:
# <AxesSubplot:xlabel='Phase [JD]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
lc.remove_nans().flatten(window_length=401).fold(period=3.5225).bin(binsize=10).plot();
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13204\1542250522.py:1: LightkurveDeprecationWarning: "binsize" was deprecated in version 2.0 and will be removed in a future version.
#         Use time_bin_size instead.
#   lc.remove_nans().flatten(window_length=401).fold(period=3.5225).bin(binsize=10).plot();

# %%
binned_lc = fold_lc.bin(binsize=10)
binned_lc.plot();
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13204\1188839381.py:1: LightkurveDeprecationWarning: "binsize" was deprecated in version 2.0 and will be removed in a future version.
#         Use time_bin_size instead.
#   binned_lc = fold_lc.bin(binsize=10)
